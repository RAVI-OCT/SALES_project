# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
#load the data
df=pd.read_csv("C:/Users/ravi/Downloads/sample_sales_data (1).csv")
df
# Out:
#            Date    Product Region   Sales  Profit  Quantity    Cost
# 0    13-04-2023  Product E   West  393.97   67.66         8  100.00
# 1    11-03-2024  Product E   West  169.27   69.99         5  296.54
# 2    10-05-2025  Product A   West   59.43   24.64        15  219.11
# 3    28-09-2023  Product A  South   86.98   60.86         1  253.60
# 4    17-04-2023  Product B  South  485.54   79.45         1  200.53
# ..          ...        ...    ...     ...     ...       ...     ...
# 995  10-01-2023  Product B  South  390.79   48.81        12  160.42
# 996  03-04-2025  Product D  North  122.75   41.28         9   76.66
# 997  08-03-2025  Product D  North  264.61   14.53        11   78.05
# 998  30-08-2023  Product C  South  373.25   14.75        10  280.19
# 999  08-09-2023  Product C  South  161.30   72.28         1  347.68
#
# [1000 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1000 non-null   object
#  1   Product   1000 non-null   object
#  2   Region    1000 non-null   object
#  3   Sales     1000 non-null   float64
#  4   Profit    1000 non-null   float64
#  5   Quantity  1000 non-null   int64
#  6   Cost      1000 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 54.8+ KB

# %%
df.dropna()
# Out:
#            Date    Product Region   Sales  Profit  Quantity    Cost
# 0    13-04-2023  Product E   West  393.97   67.66         8  100.00
# 1    11-03-2024  Product E   West  169.27   69.99         5  296.54
# 2    10-05-2025  Product A   West   59.43   24.64        15  219.11
# 3    28-09-2023  Product A  South   86.98   60.86         1  253.60
# 4    17-04-2023  Product B  South  485.54   79.45         1  200.53
# ..          ...        ...    ...     ...     ...       ...     ...
# 995  10-01-2023  Product B  South  390.79   48.81        12  160.42
# 996  03-04-2025  Product D  North  122.75   41.28         9   76.66
# 997  08-03-2025  Product D  North  264.61   14.53        11   78.05
# 998  30-08-2023  Product C  South  373.25   14.75        10  280.19
# 999  08-09-2023  Product C  South  161.30   72.28         1  347.68
#
# [1000 rows x 7 columns]

# %%
df.isnull()
# Out:
#       Date  Product  Region  Sales  Profit  Quantity   Cost
# 0    False    False   False  False   False     False  False
# 1    False    False   False  False   False     False  False
# 2    False    False   False  False   False     False  False
# 3    False    False   False  False   False     False  False
# 4    False    False   False  False   False     False  False
# ..     ...      ...     ...    ...     ...       ...    ...
# 995  False    False   False  False   False     False  False
# 996  False    False   False  False   False     False  False
# 997  False    False   False  False   False     False  False
# 998  False    False   False  False   False     False  False
# 999  False    False   False  False   False     False  False
#
# [1000 rows x 7 columns]

# %%
group_df=df.groupby("Region").agg({"Sales":['sum'],"Profit":['sum'],"Quantity":['sum','max']}).sum()
group_df
# Out:
# Sales     sum    275722.77
# Profit    sum     54660.58
# Quantity  sum     10360.00
#           max        76.00
# dtype: float64

# %%
df.columns
# Out:
# Index(['Date', 'Product', 'Region', 'Sales', 'Profit', 'Quantity', 'Cost'], dtype='object')

# %%
top_sales=df.groupby(['Date','Product'])['Sales'].sum()
top_sales
# Out:
# Date        Product
# 01-01-2023  Product E     57.90
# 01-01-2025  Product B    491.51
#             Product D    250.49
# 01-02-2024  Product D    144.82
#             Product E    284.08
#                           ...
# 31-10-2023  Product C    187.39
# 31-10-2024  Product C    101.72
#             Product D    148.05
# 31-12-2023  Product B    192.03
#             Product C    351.14
# Name: Sales, Length: 902, dtype: float64

# %%
plt.xlabel("products")
plt.ylabel("top_sales")
sns.histplot("top_sales")
plt.show()

# %%
#TO REARRANGE DATE 
Df=pd.DataFrame(df)
Df
# Out:
#            Date    Product Region   Sales  Profit  Quantity    Cost
# 0    13-04-2023  Product E   West  393.97   67.66         8  100.00
# 1    11-03-2024  Product E   West  169.27   69.99         5  296.54
# 2    10-05-2025  Product A   West   59.43   24.64        15  219.11
# 3    28-09-2023  Product A  South   86.98   60.86         1  253.60
# 4    17-04-2023  Product B  South  485.54   79.45         1  200.53
# ..          ...        ...    ...     ...     ...       ...     ...
# 995  10-01-2023  Product B  South  390.79   48.81        12  160.42
# 996  03-04-2025  Product D  North  122.75   41.28         9   76.66
# 997  08-03-2025  Product D  North  264.61   14.53        11   78.05
# 998  30-08-2023  Product C  South  373.25   14.75        10  280.19
# 999  08-09-2023  Product C  South  161.30   72.28         1  347.68
#
# [1000 rows x 7 columns]

# %%
# Convert 'Date' column to datetime
DF['Date'] = pd.to_datetime(DF['Date'])

# %%
#You can rearrange the dates in various formats. For example, to change the date format from YYYY-MM-DD to DD/MM/YYYY:
# Rearranging the date formate
DF['Formatted Date'] = DF['Date'].dt.strftime('%d/%m/%Y')
DF
# Out:
#           Date    Product Region   Sales  Profit  Quantity    Cost  \
# 0   2023-04-13  Product E   West  393.97   67.66         8  100.00
# 1   2024-03-11  Product E   West  169.27   69.99         5  296.54
# 2   2025-05-10  Product A   West   59.43   24.64        15  219.11
# 3   2023-09-28  Product A  South   86.98   60.86         1  253.60
# 4   2023-04-17  Product B  South  485.54   79.45         1  200.53
# ..         ...        ...    ...     ...     ...       ...     ...
# 995 2023-01-10  Product B  South  390.79   48.81        12  160.42
# 996 2025-04-03  Product D  North  122.75   41.28         9   76.66
# 997 2025-03-08  Product D  North  264.61   14.53        11   78.05
# 998 2023-08-30  Product C  South  373.25   14.75        10  280.19
# 999 2023-09-08  Product C  South  161.30   72.28         1  347.68
#
#     Formatted Date
# 0       13/04/2023
# 1       11/03/2024
# 2       10/05/2025
# 3       28/09/2023
# 4       17/04/2023
# ..             ...
# ...

# %%
DF['Formatted Date']=DF['Date'].dt.strftime('%d/%m/%Y')
DF
# Out:
#           Date    Product Region   Sales  Profit  Quantity    Cost  \
# 0   2023-04-13  Product E   West  393.97   67.66         8  100.00
# 1   2024-03-11  Product E   West  169.27   69.99         5  296.54
# 2   2025-05-10  Product A   West   59.43   24.64        15  219.11
# 3   2023-09-28  Product A  South   86.98   60.86         1  253.60
# 4   2023-04-17  Product B  South  485.54   79.45         1  200.53
# ..         ...        ...    ...     ...     ...       ...     ...
# 995 2023-01-10  Product B  South  390.79   48.81        12  160.42
# 996 2025-04-03  Product D  North  122.75   41.28         9   76.66
# 997 2025-03-08  Product D  North  264.61   14.53        11   78.05
# 998 2023-08-30  Product C  South  373.25   14.75        10  280.19
# 999 2023-09-08  Product C  South  161.30   72.28         1  347.68
#
#     Formatted Date
# 0       13/04/2023
# 1       11/03/2024
# 2       10/05/2025
# 3       28/09/2023
# 4       17/04/2023
# ..             ...
# ...

# %%
DF['Date'] = pd.to_datetime(DF['Date'])
DF['Formatted Date']=DF['Date'].dt.strftime('%d/%m/%Y')
DF
# Out:
#           Date    Product Region   Sales  Profit  Quantity    Cost  \
# 0   2023-04-13  Product E   West  393.97   67.66         8  100.00
# 1   2024-03-11  Product E   West  169.27   69.99         5  296.54
# 2   2025-05-10  Product A   West   59.43   24.64        15  219.11
# 3   2023-09-28  Product A  South   86.98   60.86         1  253.60
# 4   2023-04-17  Product B  South  485.54   79.45         1  200.53
# ..         ...        ...    ...     ...     ...       ...     ...
# 995 2023-01-10  Product B  South  390.79   48.81        12  160.42
# 996 2025-04-03  Product D  North  122.75   41.28         9   76.66
# 997 2025-03-08  Product D  North  264.61   14.53        11   78.05
# 998 2023-08-30  Product C  South  373.25   14.75        10  280.19
# 999 2023-09-08  Product C  South  161.30   72.28         1  347.68
#
#     Formatted Date
# 0       13/04/2023
# 1       11/03/2024
# 2       10/05/2025
# 3       28/09/2023
# 4       17/04/2023
# ..             ...
# ...

# %%
Df['Date'] = pd.to_datetime(Df['Date'])
#Df['Formatted Date']=DF['Date'].dt.strftime('%d/%m/%Y')
#Df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 Df['Date'] = pd.to_datetime(Df['Date'])
#
# NameError: name 'Df' is not defined
